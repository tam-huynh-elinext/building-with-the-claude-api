# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
client = Anthropic()
model = "claude-sonnet-4-6"

# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
  params = {
    "model": model,
    "max_tokens": 1000,
    "messages": messages,
  }
  
  if system:
    params["system"] = system
  
  response = client.messages.create(**params)
  return response.content[0].text

# %%
messages = []
system = """
    You are a Python engineer who writes very concise code.
  """

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")
answer = chat(messages, system=system)

answer
# Out:
# 'Here\'s a concise function that checks for duplicate characters in a string:\n\n```python\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n```\n\n**Examples:**\n```python\nprint(has_duplicates("hello"))   # True  (\'l\' is duplicated)\nprint(has_duplicates("world"))   # False (all unique)\nprint(has_duplicates("python"))  # False (all unique)\nprint(has_duplicates("abcabc"))  # True  (a, b, c are duplicated)\n```\n\nIf you also want to **identify which characters are duplicated**, here\'s an extended version:\n\n```python\ndef find_duplicates(s: str) -> list:\n    seen = set()\n    return list({c for c in s if c in seen or seen.add(c)})\n```\n\n**Examples:**\n```python\nprint(find_duplicates("hello"))   # [\'l\']\nprint(find_duplicates("abcabc"))  # [\'a\', \'b\', \'c\']\nprint(find_duplicates("world"))   # []\n```\n\n**How they work:**\n- `has_duplicates` — converts the string to a `set` (which removes duplicates) and compares its length to the original. If lengths differ, duplicates exist.\n- `find_duplicates` — uses a set to track seen characters and collects any character encountered more than once.'
